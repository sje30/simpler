# %% [markdown]
# ## Introduction
#
# Here is a simple notebook for R.

# %%
date()
version
# Out:
# [1] "Fri Jun 30 11:37:45 2017"
#                _
# platform       x86_64-apple-darwin15.6.0
# arch           x86_64
# os             darwin15.6.0
# system         x86_64, darwin15.6.0
# status
# major          3
# minor          4.0
# year           2017
# month          04
# day            21
# svn rev        72570
# language       R
# version.string R version 3.4.0 (2017-04-21)
# nickname       You Stupid Darkness

# %% [markdown]
# let's try a simple plot:

# %%
hist(rnorm(999))
# Out:
# Plot with title “Histogram of rnorm(999)”
